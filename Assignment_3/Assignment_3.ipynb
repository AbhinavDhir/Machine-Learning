# %%
import kagglehub

# %%
# Download latest version
path = kagglehub.dataset_download("jahias/microsoft-adventure-works-cycles-customer-data")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /Users/abhinav/.cache/kagglehub/datasets/jahias/microsoft-adventure-works-cycles-customer-data/versions/1

# %%
import numpy as np
import pandas as pd

# %%
data_cus = pd.read_csv("AWCustomers.csv") 
data_cus.head()
# Out:
#    CustomerID Title FirstName MiddleName  LastName Suffix  \
# 0       21173   NaN      Chad          C      Yuan    NaN
# 1       13249   NaN      Ryan        NaN     Perry    NaN
# 2       29350   NaN     Julia        NaN  Thompson    NaN
# 3       13503   NaN  Theodore        NaN     Gomez    NaN
# 4       22803   NaN  Marshall          J      Shan    NaN
#
#              AddressLine1 AddressLine2         City    StateProvinceName  ...  \
# 0      7090 C. Mount Hood          NaN   Wollongong      New South Wales  ...
# 1     3651 Willow Lake Rd          NaN      Shawnee     British Columbia  ...
# 2  1774 Tice Valley Blvd.          NaN  West Covina           California  ...
# 3         2103 Baldwin Dr          NaN    Liverpool              England  ...
# 4         Am Gallberg 234          NaN        Werne  Nordrhein-Westfalen  ...
#
#          Education      Occupation Gender MaritalStatus HomeOwnerFlag  \
# 0        Bachelors        Clerical      M             M             1
# ...

# %%
data_sales = pd.read_csv("AWSales.csv") 
data_sales.head()
# Out:
#    CustomerID  BikeBuyer  AvgMonthSpend
# 0       21173          1          50.97
# 1       13249          1          53.11
# 2       29350          1          54.08
# 3       13503          1          56.93
# 4       22803          1          55.41

# %%
data_cus.columns
# Out:
# Index(['CustomerID', 'Title', 'FirstName', 'MiddleName', 'LastName', 'Suffix',
#        'AddressLine1', 'AddressLine2', 'City', 'StateProvinceName',
#        'CountryRegionName', 'PostalCode', 'PhoneNumber', 'BirthDate',
#        'Education', 'Occupation', 'Gender', 'MaritalStatus', 'HomeOwnerFlag',
#        'NumberCarsOwned', 'NumberChildrenAtHome', 'TotalChildren',
#        'YearlyIncome', 'LastUpdated'],
#       dtype='object')

# %%
data_sales.columns
# Out:
# Index(['CustomerID', 'BikeBuyer', 'AvgMonthSpend'], dtype='object')

# %%
data_sales.drop(['CustomerID'], axis=1, inplace=True)

# %%
df = pd.concat([data_cus, data_sales], axis=1)
df.head()
# Out:
#    CustomerID Title FirstName MiddleName  LastName Suffix  \
# 0       21173   NaN      Chad          C      Yuan    NaN
# 1       13249   NaN      Ryan        NaN     Perry    NaN
# 2       29350   NaN     Julia        NaN  Thompson    NaN
# 3       13503   NaN  Theodore        NaN     Gomez    NaN
# 4       22803   NaN  Marshall          J      Shan    NaN
#
#              AddressLine1 AddressLine2         City    StateProvinceName  ...  \
# 0      7090 C. Mount Hood          NaN   Wollongong      New South Wales  ...
# 1     3651 Willow Lake Rd          NaN      Shawnee     British Columbia  ...
# 2  1774 Tice Valley Blvd.          NaN  West Covina           California  ...
# 3         2103 Baldwin Dr          NaN    Liverpool              England  ...
# 4         Am Gallberg 234          NaN        Werne  Nordrhein-Westfalen  ...
#
#   Gender MaritalStatus HomeOwnerFlag NumberCarsOwned NumberChildrenAtHome  \
# ...

# %%
df.columns
# Out:
# Index(['CustomerID', 'Title', 'FirstName', 'MiddleName', 'LastName', 'Suffix',
#        'AddressLine1', 'AddressLine2', 'City', 'StateProvinceName',
#        'CountryRegionName', 'PostalCode', 'PhoneNumber', 'BirthDate',
#        'Education', 'Occupation', 'Gender', 'MaritalStatus', 'HomeOwnerFlag',
#        'NumberCarsOwned', 'NumberChildrenAtHome', 'TotalChildren',
#        'YearlyIncome', 'LastUpdated', 'BikeBuyer', 'AvgMonthSpend'],
#       dtype='object')

# %%
df.drop(['Title','Suffix','AddressLine1','AddressLine2','NumberCarsOwned','NumberChildrenAtHome','TotalChildren','LastUpdated','PostalCode','PhoneNumber','HomeOwnerFlag'], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['CustomerID', 'FirstName', 'MiddleName', 'LastName', 'City',
#        'StateProvinceName', 'CountryRegionName', 'BirthDate', 'Education',
#        'Occupation', 'Gender', 'MaritalStatus', 'YearlyIncome', 'BikeBuyer',
#        'AvgMonthSpend'],
#       dtype='object')

# %%
df.head()
# Out:
#    CustomerID FirstName MiddleName  LastName         City  \
# 0       21173      Chad          C      Yuan   Wollongong
# 1       13249      Ryan        NaN     Perry      Shawnee
# 2       29350     Julia        NaN  Thompson  West Covina
# 3       13503  Theodore        NaN     Gomez    Liverpool
# 4       22803  Marshall          J      Shan        Werne
#
#      StateProvinceName CountryRegionName   BirthDate        Education  \
# 0      New South Wales         Australia  1987-11-13        Bachelors
# 1     British Columbia            Canada  1972-07-21  Partial College
# 2           California     United States  1985-11-09        Bachelors
# 3              England    United Kingdom  1977-10-18  Partial College
# 4  Nordrhein-Westfalen           Germany  1975-02-05  Partial College
#
#        Occupation Gender MaritalStatus  YearlyIncome  BikeBuyer  AvgMonthSpend
# 0        Clerical      M             M         81916        1.0          50.97
# ...

# %%
df.drop(['FirstName','MiddleName','LastName'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    CustomerID         City    StateProvinceName CountryRegionName   BirthDate  \
# 0       21173   Wollongong      New South Wales         Australia  1987-11-13
# 1       13249      Shawnee     British Columbia            Canada  1972-07-21
# 2       29350  West Covina           California     United States  1985-11-09
# 3       13503    Liverpool              England    United Kingdom  1977-10-18
# 4       22803        Werne  Nordrhein-Westfalen           Germany  1975-02-05
#
#          Education      Occupation Gender MaritalStatus  YearlyIncome  \
# 0        Bachelors        Clerical      M             M         81916
# 1  Partial College        Clerical      M             M         81076
# 2        Bachelors        Clerical      F             S         86387
# 3  Partial College  Skilled Manual      M             M         61481
# 4  Partial College  Skilled Manual      M             S         51804
#
#    BikeBuyer  AvgMonthSpend
# 0        1.0          50.97
# ...

# %%
df["CustomerID"].value_counts()
# Out:
# CustomerID
# 21647    2
# 23192    2
# 26829    2
# 13385    2
# 24334    2
#         ..
# 27615    1
# 23310    1
# 19682    1
# 22875    1
# 16676    1
# Name: count, Length: 18355, dtype: int64

# %%
df.isnull().sum()
# Out:
# CustomerID           0
# City                 0
# StateProvinceName    0
# CountryRegionName    0
# BirthDate            0
# Education            0
# Occupation           0
# Gender               0
# MaritalStatus        0
# YearlyIncome         0
# BikeBuyer            6
# AvgMonthSpend        6
# dtype: int64

# %%
print(pd.isna(df))
# Out:
#        CustomerID   City  StateProvinceName  CountryRegionName  BirthDate  \
# 0           False  False              False              False      False
# 1           False  False              False              False      False
# 2           False  False              False              False      False
# 3           False  False              False              False      False
# 4           False  False              False              False      False
# ...           ...    ...                ...                ...        ...
# 18356       False  False              False              False      False
# 18357       False  False              False              False      False
# 18358       False  False              False              False      False
# 18359       False  False              False              False      False
# 18360       False  False              False              False      False
#
#        Education  Occupation  Gender  MaritalStatus  YearlyIncome  BikeBuyer  \
# ...

# %%
from sklearn.impute import SimpleImputer

# %%
df.head()
# Out:
#    CustomerID         City    StateProvinceName CountryRegionName   BirthDate  \
# 0       21173   Wollongong      New South Wales         Australia  1987-11-13
# 1       13249      Shawnee     British Columbia            Canada  1972-07-21
# 2       29350  West Covina           California     United States  1985-11-09
# 3       13503    Liverpool              England    United Kingdom  1977-10-18
# 4       22803        Werne  Nordrhein-Westfalen           Germany  1975-02-05
#
#          Education      Occupation Gender MaritalStatus  YearlyIncome  \
# 0        Bachelors        Clerical      M             M         81916
# 1  Partial College        Clerical      M             M         81076
# 2        Bachelors        Clerical      F             S         86387
# 3  Partial College  Skilled Manual      M             M         61481
# 4  Partial College  Skilled Manual      M             S         51804
#
#    BikeBuyer  AvgMonthSpend
# 0        1.0          50.97
# ...

# %%
mean_imputer = SimpleImputer(missing_values=np.nan, strategy='mean') 
df['AvgMonthSpend'] = mean_imputer.fit_transform(df[['AvgMonthSpend']].values)

# %%
df.isnull().sum()
# Out:
# CustomerID           0
# City                 0
# StateProvinceName    0
# CountryRegionName    0
# BirthDate            0
# Education            0
# Occupation           0
# Gender               0
# MaritalStatus        0
# YearlyIncome         0
# BikeBuyer            6
# AvgMonthSpend        0
# dtype: int64

# %%
mode_imputer = SimpleImputer(strategy='most_frequent')
df['BikeBuyer'] = mode_imputer.fit_transform(df[['BikeBuyer']])

# %%
df.isnull().sum()
# Out:
# CustomerID           0
# City                 0
# StateProvinceName    0
# CountryRegionName    0
# BirthDate            0
# Education            0
# Occupation           0
# Gender               0
# MaritalStatus        0
# YearlyIncome         0
# BikeBuyer            0
# AvgMonthSpend        0
# dtype: int64

# %%
#b
bins = np.linspace(min(df['YearlyIncome']), max(df['YearlyIncome']), 4) 
group_names = ['lower','lower middle','upper middle','upper']

# %%
df['YearlyIncome'] = pd.cut(df['YearlyIncome'], bins, labels=group_names)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 df['YearlyIncome'] = pd.cut(df['YearlyIncome'], bins, labels=group_names)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/reshape/tile.py:257, in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates, ordered)
#     254     if not bins.is_monotonic_increasing:
#     255         raise ValueError("bins must increase monotonically.")
# --> 257 fac, bins = _bins_to_cuts(
#     258     x_idx,
#     259     bins,
#     260     right=right,
#     261     labels=labels,
#     262     precision=precision,
#     263     include_lowest=include_lowest,
#     264     duplicates=duplicates,
#     265     ordered=ordered,
#     266 )
#     268 return _postprocess_for_cut(fac, bins, retbins, original)
#
# ...
